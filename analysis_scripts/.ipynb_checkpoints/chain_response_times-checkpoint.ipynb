# %%
import sys
import collections
import bt2
import pandas as pd
import numpy as np

# %%
trace_path = "/home/wagle/.ros/tracing/vanilla-ros-graph-gen-20241020-170127/"

# %%
invocations = {}
it = bt2.TraceCollectionMessageIterator(trace_path)
for msg in it:
    # We only care about event messages
    if type(msg) is not bt2._EventMessageConst:
        continue

    # Event of the event message
    event = msg.event

    # Keep only `unc_ros_graph_generator` events
    if 'unc_ros_graph_generator:' not in event.cls.name:
        continue
    if 'unc_ros_graph_generator:subscribe' in event.cls.name:
        continue

    invocation_count = str(event.payload_field['invocation_count'])
    # Check if the key exists; if not, create a new list
    if invocation_count not in invocations:
        invocations[invocation_count] = []

    # Insert the new element into the list
    invocations[invocation_count].append(msg)

# %%
message = "There were {} invocations of the source node".format(len(invocations.keys()))
print(message)
# Out:
# There were 1513 invocations of the source node

# %%
# Keeps track of the source callbacks' names and start times per invocation
sources = {"source" : None }

# Keeps track of the leaf callbacks' names and end times per invocation
leaves = {"N1_CB_3": None, "N2_CB_3": None}

num_invocations = len(invocations.keys())
num_leaves = len(leaves.keys())
num_sources = len(sources.keys())

# invocation #, source callback name, source start timestamp (ns), leaf callback name, leaf end timestamp (ns), response time (ns)
num_fields = 5
invocations_numpy = np.ones((num_invocations * num_sources * num_leaves, 6), dtype=object)
curr_row = 0

for invocation_num in invocations.keys():
    for msg in invocations[invocation_num]:
        event_type = msg.event.cls.name
        name = ""
        if 'callback_' in event_type:
            name = msg.event.payload_field['callback_name']

            if 'callback_begin' in event_type and name in sources: 
                sources[name] = msg.default_clock_snapshot.ns_from_origin

            elif 'callback_end' in event_type and name in leaves:
                leaves[name] = msg.default_clock_snapshot.ns_from_origin
                for source in sources:
                    start_ts = sources[source]
                    end_ts = leaves[name]
                    assert(start_ts != None and end_ts != None)
                    assert(end_ts >= start_ts)
                
                    resp_time = end_ts - start_ts
                    invocations_numpy[curr_row] = np.array([int(invocation_num), source, start_ts, str(name), end_ts, resp_time], dtype=object)
                    curr_row = curr_row + 1
                
        if 'publish' in event_type:
            name = msg.event.payload_field['sender_callback_name']
            topic = msg.event.payload_field['topic_name']

# %%
column_names = ['Invocation #', 'Source', 'Source start time (ns)', 'Leaf', 'Leaf end time (ns)', 'Chain Resp Time (ns)']
df = pd.DataFrame(invocations_numpy, columns=column_names)
df = df.astype({
    'Invocation #': 'int64',
    'Source': 'object',
    'Source start time (ns)': 'int64',
    'Leaf': 'object',
    'Leaf end time (ns)': 'int64',
    'Chain Resp Time (ns)': 'int64'
})
print(df)
# Out:
#       Invocation #  Source  Source start time (ns)     Leaf  \
# 0                0  source     1729458127618824380  N1_CB_3
# 1                0  source     1729458127618824380  N2_CB_3
# 2                1  source     1729458127640976776  N1_CB_3
# 3                1  source     1729458127640976776  N2_CB_3
# 4                2  source     1729458127673944807  N1_CB_3
# ...            ...     ...                     ...      ...
# 3021          1510  source     1729458177437941575  N2_CB_3
# 3022          1511  source     1729458177470950280  N1_CB_3
# 3023          1511  source     1729458177470950280  N2_CB_3
# 3024             1       1                       1        1
# 3025             1       1                       1        1
#
#        Leaf end time (ns)  Chain Resp Time (ns)
# 0     1729458127623422397               4598017
# 1     1729458127623976489               5152109
# 2     1729458127644174610               3197834
# 3     1729458127644578521               3601745
# 4     1729458127677128702               3183895
# ...                   ...                   ...
# 3021  1729458177441601334               3659759
# 3022  1729458177474312323               3362043
# 3023  1729458177474741815               3791535
# 3024                    1                     1
# 3025                    1                     1
#
# [3026 rows x 6 columns]

# %%
import itertools
source_leaf_pairs = list(itertools.product(sources, leaves))
for pair in source_leaf_pairs:
    filtered = df[(df['Source'] == pair[0]) & (df['Leaf'] == pair[1])]
    mean_resp_time = filtered['Chain Resp Time (ns)'].mean()
    print("({} --> {}) mean response time = {:.3f} ns = {:.3f} ms".format(pair[0], pair[1], mean_resp_time, mean_resp_time/1000000))
# Out:
#       Invocation #  Source  Source start time (ns)     Leaf  \
# 0                0  source     1729458127618824380  N1_CB_3
# 2                1  source     1729458127640976776  N1_CB_3
# 4                2  source     1729458127673944807  N1_CB_3
# 6                3  source     1729458127706918412  N1_CB_3
# 8                4  source     1729458127739973779  N1_CB_3
# ...            ...     ...                     ...      ...
# 3014          1507  source     1729458177338796769  N1_CB_3
# 3016          1508  source     1729458177371956031  N1_CB_3
# 3018          1509  source     1729458177404978416  N1_CB_3
# 3020          1510  source     1729458177437941575  N1_CB_3
# 3022          1511  source     1729458177470950280  N1_CB_3
#
#        Leaf end time (ns)  Chain Resp Time (ns)
# 0     1729458127623422397               4598017
# 2     1729458127644174610               3197834
# 4     1729458127677128702               3183895
# 6     1729458127710157467               3239055
# 8     1729458127743258284               3284505
# ...                   ...                   ...
# 3014  1729458177342762422               3965653
# 3016  1729458177375225398               3269367
# 3018  1729458177408358323               3379907
# 3020  1729458177441189181               3247606
# 3022  1729458177474312323               3362043
#
# [1512 rows x 6 columns]
# (source --> N1_CB_3) mean response time = 3486376.719 ns = 3.486 ms
#       Invocation #  Source  Source start time (ns)     Leaf  \
# 1                0  source     1729458127618824380  N2_CB_3
# 3                1  source     1729458127640976776  N2_CB_3
# 5                2  source     1729458127673944807  N2_CB_3
# 7                3  source     1729458127706918412  N2_CB_3
# 9                4  source     1729458127739973779  N2_CB_3
# ...            ...     ...                     ...      ...
# 3015          1507  source     1729458177338796769  N2_CB_3
# 3017          1508  source     1729458177371956031  N2_CB_3
# 3019          1509  source     1729458177404978416  N2_CB_3
# 3021          1510  source     1729458177437941575  N2_CB_3
# 3023          1511  source     1729458177470950280  N2_CB_3
#
#        Leaf end time (ns)  Chain Resp Time (ns)
# 1     1729458127623976489               5152109
# 3     1729458127644578521               3601745
# 5     1729458127677532763               3587956
# 7     1729458127710565911               3647499
# 9     1729458127743672846               3699067
# ...                   ...                   ...
# 3015  1729458177343177289               4380520
# 3017  1729458177375640590               3684559
# 3019  1729458177408767145               3788729
# 3021  1729458177441601334               3659759
# 3023  1729458177474741815               3791535
#
# [1512 rows x 6 columns]
# (source --> N2_CB_3) mean response time = 3908774.083 ns = 3.909 ms

# %%
# Plot a line chart with the Invocation # vs Chain response time for each chain
# Plotting the line chart
import matplotlib.pyplot as plt
plt.figure(figsize=(40, 20))  # Optional: Set the figure size
plt.title('Line Chart of Y vs. X')  # Title of the chart
plt.xlabel('X')  # Label for the x-axis
plt.ylabel('Y')  # Label for the y-axis
plt.grid(True)  # Optional: Add grid


for pair in source_leaf_pairs:
    source,leaf = pair
    chain_label = "{} --> {}".format(source,leaf)
    filtered = df[(df['Source'] == source) & (df['Leaf'] == leaf)]
    print(filtered[['Invocation #','Chain Resp Time (ns)']])
    plt.plot(filtered['Invocation #'], filtered['Chain Resp Time (ns)'], marker='o', label=chain_label)  # First dataset
plt.legend()  # Show legend
plt.show()  # Display the plot
# Out:
#       Invocation #  Chain Resp Time (ns)
# 0                0               4598017
# 2                1               3197834
# 4                2               3183895
# 6                3               3239055
# 8                4               3284505
# ...            ...                   ...
# 3014          1507               3965653
# 3016          1508               3269367
# 3018          1509               3379907
# 3020          1510               3247606
# 3022          1511               3362043
#
# [1512 rows x 2 columns]
#       Invocation #  Chain Resp Time (ns)
# 1                0               5152109
# 3                1               3601745
# 5                2               3587956
# 7                3               3647499
# 9                4               3699067
# ...            ...                   ...
# 3015          1507               4380520
# 3017          1508               3684559
# 3019          1509               3788729
# 3021          1510               3659759
# 3023          1511               3791535
#
# [1512 rows x 2 columns]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Enable Bokeh in Jupyter Notebook (if using Jupyter)
output_notebook()

# Create a Bokeh figure
p = figure(title="Line Plot with Bokeh", x_axis_label='X-axis', y_axis_label='Y-axis')

# Add a line renderer
for pair in source_leaf_pairs:
    source,leaf = pair
    chain_label = "{} --> {}".format(source,leaf)
    filtered = df[(df['Source'] == source) & (df['Leaf'] == leaf)]
    print(filtered)
    p.line(filtered['Invocation #'], filtered['Chain Resp Time (ns)'], line_width=2, legend_label="Y values", color="blue", marker="circle")

# Show the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fd70660b-e01d-4834-bd78-9d65ff3f254c">Loading BokehJS ...</span>
#     </div>
#       Invocation #  Source  Source start time (ns)     Leaf  \
# 0                0  source     1729458127618824380  N1_CB_3
# 2                1  source     1729458127640976776  N1_CB_3
# 4                2  source     1729458127673944807  N1_CB_3
# 6                3  source     1729458127706918412  N1_CB_3
# 8                4  source     1729458127739973779  N1_CB_3
# ...            ...     ...                     ...      ...
# 3014          1507  source     1729458177338796769  N1_CB_3
# 3016          1508  source     1729458177371956031  N1_CB_3
# 3018          1509  source     1729458177404978416  N1_CB_3
# 3020          1510  source     1729458177437941575  N1_CB_3
# 3022          1511  source     1729458177470950280  N1_CB_3
#
#        Leaf end time (ns)  Chain Resp Time (ns)
# 0     1729458127623422397               4598017
# 2     1729458127644174610               3197834
# 4     1729458127677128702               3183895
# 6     1729458127710157467               3239055
# 8     1729458127743258284               3284505
# ...                   ...                   ...
# 3014  1729458177342762422               3965653
# 3016  1729458177375225398               3269367
# 3018  1729458177408358323               3379907
# 3020  1729458177441189181               3247606
# 3022  1729458177474312323               3362043
#
# [1512 rows x 6 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[273], line 16
#      14     filtered = df[(df['Source'] == source) & (df['Leaf'] == leaf)]
#      15     print(filtered)
# ---> 16     p.line(filtered['Invocation #'], filtered['Chain Resp Time (ns)'], line_width=2, legend_label="Y values", color="blue", marker="circle")
#      18 # Show the plot
#      19 show(p)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/plotting/_decorators.py:89, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      87 if self.coordinates is not None:
#      88     kwargs.setdefault("coordinates", self.coordinates)
# ---> 89 return create_renderer(glyphclass, self.plot, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/plotting/_renderer.py:113, in create_renderer(glyphclass, plot, **kwargs)
#     110 # handle the mute glyph, we always set one
#     111 muted_visuals = pop_visuals(glyphclass, kwargs, prefix='muted_', defaults=glyph_visuals, override_defaults={'alpha':0.2})
# --> 113 glyph = make_glyph(glyphclass, kwargs, glyph_visuals)
#     114 nonselection_glyph = make_glyph(glyphclass, kwargs, nonselection_visuals)
#     115 selection_glyph = make_glyph(glyphclass, kwargs, selection_visuals)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/plotting/_renderer.py:142, in make_glyph(glyphclass, kws, extra)
#     140 kws = kws.copy()
#     141 kws.update(extra)
# --> 142 return glyphclass(**kws)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/models/glyphs.py:978, in Line.__init__(self, *args, **kwargs)
#     977 def __init__(self, *args, **kwargs) -> None:
# --> 978     super().__init__(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/models/glyph.py:107, in ConnectedXYGlyph.__init__(self, *args, **kwargs)
#     106 def __init__(self, *args, **kwargs) -> None:
# --> 107     super().__init__(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/models/glyph.py:85, in XYGlyph.__init__(self, *args, **kwargs)
#      84 def __init__(self, *args, **kwargs) -> None:
# ---> 85     super().__init__(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/models/glyph.py:117, in LineGlyph.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args, **kwargs) -> None:
# --> 117     super().__init__(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/models/glyph.py:63, in Glyph.__init__(self, *args, **kwargs)
#      62 def __init__(self, *args, **kwargs) -> None:
# ---> 63     super().__init__(*args, **kwargs)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/model/model.py:119, in Model.__init__(self, *args, **kwargs)
#     116 if "id" in kwargs:
#     117     raise ValueError("initializing 'id' is not allowed")
# --> 119 super().__init__(**kwargs)
#     120 default_theme.apply_to_model(self)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/core/has_props.py:304, in HasProps.__init__(self, **properties)
#     302     if value is Undefined or value is Intrinsic:
#     303         continue
# --> 304     setattr(self, name, value)
#     306 initialized = set(properties.keys())
#     307 for name in self.properties(_with_props=True): # avoid set[] for deterministic behavior
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/core/has_props.py:342, in HasProps.__setattr__(self, name, value)
#     339 if isinstance(descriptor, property): # Python property
#     340     return super().__setattr__(name, value)
# --> 342 self._raise_attribute_error_with_matches(name, properties)
#
# File ~/myenv/lib/python3.12/site-packages/bokeh/core/has_props.py:377, in HasProps._raise_attribute_error_with_matches(self, name, properties)
#     374 if not matches:
#     375     matches, text = sorted(properties), "possible"
# --> 377 raise AttributeError(f"unexpected attribute {name!r} to {self.__class__.__name__}, {text} attributes are {nice_join(matches)}")
#
# AttributeError: unexpected attribute 'marker' to Line, possible attributes are decorations, js_event_callbacks, js_property_callbacks, line_alpha, line_cap, line_color, line_dash, line_dash_offset, line_join, line_width, name, subscribed_events, syncable, tags, x or y
